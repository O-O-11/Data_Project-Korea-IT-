# %% [markdown]
# # 0. 데이터 불러오기
# 그런데 BP_PHQ(정신건강) 관련 조사는 순환조사라 짝수년에만 이루어짐.
# - 그래서 짝수년의 데이터만 불러오기

# %%
import numpy as np
import pandas as pd
import seaborn as sns
 
pd.set_option('display.max_rows', None) # 모두 출력하기

# file23 = "../../data/hn23_all.csv"
file22 = "../../data/hn22_all.csv"
# file21 = "../../data/hn21_all.csv"
file20 = "../../data/hn20_all.csv"
#file19 = "../../data/hn19_all.csv"
file18 = "../../data/hn18_all.csv"
# file17 = "../../data/hn17_all.csv"
file16 = "../../data/hn16_all.csv"
# file15 = "../../data/hn15_all.csv"
file14 = "../../data/hn14_all.csv"
# file13 = "../../data/hn13_all.csv"


#data_23 = pd.read_csv(file23)
data_22 = pd.read_csv(file22)
#data_21 = pd.read_csv(file21)
data_20 = pd.read_csv(file20)
#data_19 = pd.read_csv(file19)
data_18 = pd.read_csv(file18)
#data_17 = pd.read_csv(file17)
data_16 = pd.read_csv(file16)
#data_15 = pd.read_csv(file15)
data_14 = pd.read_csv(file14)
# Out:
# C:\Users\hys03\AppData\Local\Temp\ipykernel_23400\2376592880.py:21: DtypeWarning: Columns (81,111,183,199,269,275,288,362,367,368,373,407,642) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_22 = pd.read_csv(file22)
# C:\Users\hys03\AppData\Local\Temp\ipykernel_23400\2376592880.py:23: DtypeWarning: Columns (140,208,317,376,474,479,485,511,521,533,680) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_20 = pd.read_csv(file20)
# C:\Users\hys03\AppData\Local\Temp\ipykernel_23400\2376592880.py:25: DtypeWarning: Columns (146,209,220,274,283,318,339,355,436,525,526,530,531,536,570,585,587,602,662) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_18 = pd.read_csv(file18)
# C:\Users\hys03\AppData\Local\Temp\ipykernel_23400\2376592880.py:27: DtypeWarning: Columns (208,219,285,294,305,332,345,366,455,461,496,548,553,601,658,693) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_16 = pd.read_csv(file16)
# C:\Users\hys03\AppData\Local\Temp\ipykernel_23400\2376592880.py:29: DtypeWarning: Columns (147,198,202,267,288,451,609,611) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_14 = pd.read_csv(file14)

# %% [markdown]
# 총 629 columns
#
# - 0 ~ 297 : 건강설문조사
#
# - 298 ~ 545 : 검진기본조사
#
# - 546 ~ 628 : 영양조사

# %% [markdown]
# -----
# # 1. 건강설문조사 : test1_22

# %% [markdown]
# 1. 가구조사
# 2. 이환
#     1. 주관적 건강상태
#     2. 고혈압
#     3. 이상지질혈증
#     4. 당뇨병
#     5. 천식
#     6. 아토피피부염
#     7. 알레르기비염
#     8. 부비동염
#     9. 중이염
#     10. 콩팥병
#     11. 폐쇄성수면무호흡증
# 3. 의료이용
# 4. 예방접종 및 건강검진
# 5. 활동 제한 및 삶의 질
# 6. 손상(사고 및 중독)
# 7. 입원 및 외래이용
# 8. 교육
# 9. 경제활동
# 10. 비만 및 체중조절
# 11. 음주
# 12. 안전의식
# 13. 수면건강
# 14. 정신건강
# 15. 흡연
# 16. 신체활동
# 17. 여성건강

# %%
data_year = [data_22, data_20, data_18, data_16, data_14]
test_dic = {}   # 해당연도 : 해당 연도의 건강설문조사

for i, d in enumerate(data_year) : 
    end_idx = d.columns.get_loc("HE_fst")
    print(f"{2022-2*i}년 검진기본조사 시작열 : ",end_idx)
    test_dic[2022-2*i] = d.iloc[:, :end_idx]
    print(f"{2022-2*i}년 건강설문조사 shape : {test_dic[2022-2*i].shape}\n")
# Out:
# 2022년 검진기본조사 시작열 :  340
# 2022년 건강설문조사 shape : (6265, 340)
#
# 2020년 검진기본조사 시작열 :  444
# 2020년 건강설문조사 shape : (7359, 444)
#
# 2018년 검진기본조사 시작열 :  493
# 2018년 건강설문조사 shape : (7992, 493)
#
# 2016년 검진기본조사 시작열 :  510
# 2016년 건강설문조사 shape : (8150, 510)
#
# 2014년 검진기본조사 시작열 :  412
# 2014년 건강설문조사 shape : (7550, 412)

# %% [markdown]
# ---
# # 2. 2022년을 기준으로, 필요없는 대분류 제거
# 2. 이환 : 주관적 건강상태 제외 모두 삭제
# 3. 의료이용
# 4. 예방접종 및 건강검진
# 7. 입원 및 외래이용
# 12. 안전의식
# 17. 여성건강

# %%
# 2 ~ 4 삭제 ===
test1_22 = test_dic[2022]
print(test1_22.columns.get_loc("DI1_dg"))
print(test1_22.columns.get_loc("BH2_61"))
test1_22 = test1_22.drop(test1_22.columns[44:86], axis=1)


# 7 ===
test1_22 = test1_22.drop(columns = ["MH1_yr", "MH1_1", "MO1_wk", "MO1_1"], axis=1)

# 12 ===
print(test1_22.columns.get_loc("BA2_12"))
print(test1_22.columns.get_loc("sc_seatblt3"))

test1_22 = test1_22.drop(test1_22.columns[155:171], axis=1)

# 17 ===
print(test1_22.columns.get_loc("LW_ms"))
test1_22 = test1_22.drop(test1_22.columns[263:], axis=1)

test_dic[2022] = test1_22

print("제거 후 :", test_dic[2022].shape)
# Out:
# 44
# 85
# 155
# 170
# 263
# 제거 후 : (6265, 263)

# %% [markdown]
# ### 제거 후 남은 항목
# 0. 기본 변수
# 1. 가구조사
# 2. 이환
#     1. 주관적 건강상태
# 5. 활동 제한 및 삶의 질
# 6. 손상(사고 및 중독)
# 7. 입원 및 외래이용
# 8. 교육
# 9. 경제활동
# 10. 비만 및 체중조절
# 11. 음주
# 13. 수면건강
# 14. 정신건강
# 15. 흡연
# 16. 신체활동

# %% [markdown]
# ---
# # 3. 다른 연도 (2022 ~ 2014) 와 공통 열 찾고 모든 데이터 합치기

# %%
test_dic[2014] = test_dic[2014].rename(columns={"id": "ID"})

target = "ID"

for year, df in test_dic.items():
    cols = [col for col in df.columns if col.startswith(target)]
    print(year, cols)
# Out:
# 2022 ['ID', 'ID_fam', 'ID_F', 'ID_M']
# 2020 ['ID', 'ID_fam', 'ID_F', 'ID_M']
# 2018 ['ID', 'ID_fam', 'ID_F', 'ID_M']
# 2016 ['ID', 'ID_fam', 'ID_F', 'ID_M']
# 2014 ['ID', 'ID_fam']

# %%
# 1) 공통열 찾기
dfs = list(test_dic.values())

common_cols = set(dfs[0].columns)
for df in dfs[1:]:
    common_cols = common_cols.intersection(df.columns)

common_cols = list(common_cols)
print(len(common_cols))

'''
bp_cols = [col for col in common_cols if col.startswith("BP")]
print(bp_cols) => 잘 됐는지 확인용
'''

# 2) 데이터 합치기
test1_all = pd.concat([df[common_cols] for df in dfs], ignore_index=True)
print(test1_all.shape)
# Out:
# 164
# (37316, 164)

# %% [markdown]
# # 4. 주관식, 기타(생성변수) 제거
# - "기타상세" -> 서술형에 해당하는 열 drop
# - `"occp", "edu"`: 최빈값
# - `"ID_F", "ID_M"` : 값이 있으면 1, NaN 이면 0

# %%
test1_all = pd.concat([df[common_cols] for df in dfs], ignore_index=True)

# 주관식, 기타 제거
test1_all.drop(["ID_fam", "year", "psu", "LQ4_24", "age_month", "incm5", "ho_incm5", 
                "mh_PHQ_S", "EQ5D", "pa_aerobic","sm_presnt", "mh_stress", "dr_month", 
                "wt_tot", "wt_ntr", "ainc", "wt_itvex", "BS6_4", "mod_d", "wt_hs", 
                "kstrata", ], axis = 1, inplace = True)

# 결과
missing = test1_all.isna().sum()[test1_all.isna().sum() > 0]
print("결측치가 있는 열 개수 :", missing.shape[0])
print(missing)
# Out:
# 결측치가 있는 열 개수 : 125
# BS3_2        1637
# D_2_1        1637
# BE3_73       1637
# EC_stt_2     1637
# EC_pedu_2    1592
# D_2_wk       1637
# BE3_86       1637
# edu          3425
# BP1          1637
# BS12_2       1637
# BE3_81       1637
# LQ4_23       1637
# LQ_1EQL      1637
# EC_wht_23    1637
# BE3_88       1637
# BP6_10       1637
# LQ4_15       1637
# BP_PHQ_5     1637
# LQ4_00       1637
# BO2_1        1637
# LQ2_mn       1637
# EC_lgw_4     1637
# BD1          1637
# BS6_2_2      1637
# EC1_1        1637
# BP_PHQ_9     1637
# LQ4_11       1637
# BP_PHQ_8     1637
# BE3_76       1637
# BS3_1        1637
# LQ4_07       1637
# BP7          1637
# EC_stt_1     1637
# BD2_31       1637
# LQ4_01       1637
# D_1_1        1637
# BS6_2        1637
# BS12_1       1637
# LQ_3EQL      1637
# LQ4_05       1637
# LQ_2EQL      1637
# BP_PHQ_6     1637
# LQ4_03       1637
# BO1_1        1637
# BE3_94       1637
# BD2_1        1637
# BS9_2        1637
# BS10_2       1637
# BS2          1637
# EC_wht_0     1637
# BP_PHQ_3     1637
# BE3_72       1637
# BP_PHQ_2     1637
# BS6_4_2      1637
# BE3_83       1637
# BE3_32       1637
# BO1          1637
# BS10_3       1637
# BE3_75       1637
# BP6_31       1637
# BO1_2        1637
# BE8_1        1637
# BS6_3        1637
# LQ_4EQL      1637
# BD2_32       1637
# BD7_4        1637
# BS6_4_1      1637
# LQ4_04       1637
# BE3_93       1637
# BE3_77       1637
# EC_pedu_1    1592
# EC_lgw_2     1637
# BE3_92       1637
# ho_incm       142
# LQ4_02       1637
# BE3_85       1637
# BE3_87       1637
# CH2_1        1637
# BD7_5        1637
# LQ4_21       1637
# EC_occp      1637
# BE3_71       1637
# BP_PHQ_7     1637
# graduat      1637
# LQ4_08       1637
# BS10_1       1637
# incm          142
# BS13         1637
# LQ1_mn       1637
# BE3_31       1637
# BO1_3        1637
# BE3_91       1637
# BD1_11       1637
# BE3_82       1637
# LQ1_sb       1637
# LQ_5EQL      1637
# BE3_33       1637
# BP6_2        1637
# BE3_78       1637
# LQ4_10       1637
# educ         1637
# BP_PHQ_1     1637
# BE3_84       1637
# LQ4_22       1637
# BS5_1        1637
# LQ4_14       1637
# BS3_3        1637
# BS1_1        1637
# LQ4_16       1637
# BP_PHQ_4     1637
# LQ2_ab       1637
# LQ4_09       1637
# CH2_2        1637
# BE8_2        1637
# BS6_2_1      1637
# BP5          1637
# BE5_1        1637
# BD2          1637
# LQ4_13       1637
# EC_lgw_5     1637
# BS8_2        1637
# BE3_74       1637
# occp         9113
# LQ4_06       1637
# LQ4_12       1637
# dtype: int64

# %% [markdown]
# # 5. 결측치 처리

# %%
# 결측치 처리
m1 = test1_all["occp"].mode()[0]    # 무직
m2 = test1_all["edu"].mode()[0]     # 초졸이하;;

test1_all["occp"] = test1_all["occp"].fillna(m1)
test1_all["edu"] = test1_all["edu"].fillna(m2)

# 결과
missing = test1_all.isna().sum()[test1_all.isna().sum() > 0]
print("결측치가 있는 열 개수 :", missing.shape[0])
print(missing)
# Out:
# 결측치가 있는 열 개수 : 125
# BS3_2        1637
# D_2_1        1637
# BE3_73       1637
# EC_stt_2     1637
# EC_pedu_2    1592
# D_2_wk       1637
# BE3_86       1637
# BP1          1637
# BS12_2       1637
# BE3_81       1637
# LQ4_23       1637
# LQ_1EQL      1637
# EC_wht_23    1637
# BE3_88       1637
# BP6_10       1637
# LQ4_15       1637
# BP_PHQ_5     1637
# LQ4_00       1637
# BO2_1        1637
# LQ2_mn       1637
# EC_lgw_4     1637
# BD1          1637
# BS6_2_2      1637
# EC1_1        1637
# BP_PHQ_9     1637
# LQ4_11       1637
# ho_incm5      142
# BP_PHQ_8     1637
# BE3_76       1637
# BS3_1        1637
# LQ4_07       1637
# BP7          1637
# EC_stt_1     1637
# BD2_31       1637
# LQ4_01       1637
# D_1_1        1637
# BS6_2        1637
# BS12_1       1637
# LQ_3EQL      1637
# LQ4_05       1637
# LQ_2EQL      1637
# BP_PHQ_6     1637
# LQ4_03       1637
# BO1_1        1637
# BE3_94       1637
# BD2_1        1637
# BS9_2        1637
# BS10_2       1637
# BS2          1637
# EC_wht_0     1637
# BP_PHQ_3     1637
# BE3_72       1637
# BP_PHQ_2     1637
# BS6_4_2      1637
# BE3_83       1637
# BE3_32       1637
# BO1          1637
# BS10_3       1637
# BE3_75       1637
# BP6_31       1637
# BO1_2        1637
# BE8_1        1637
# BS6_3        1637
# LQ_4EQL      1637
# BD2_32       1637
# BD7_4        1637
# BS6_4_1      1637
# LQ4_04       1637
# BE3_93       1637
# BE3_77       1637
# EC_pedu_1    1592
# EC_lgw_2     1637
# BE3_92       1637
# ho_incm       142
# LQ4_02       1637
# BE3_85       1637
# BE3_87       1637
# CH2_1        1637
# BD7_5        1637
# LQ4_21       1637
# EC_occp      1637
# BE3_71       1637
# BP_PHQ_7     1637
# graduat      1637
# LQ4_08       1637
# BS10_1       1637
# incm          142
# BS13         1637
# LQ1_mn       1637
# BE3_31       1637
# incm5         142
# BO1_3        1637
# BE3_91       1637
# BD1_11       1637
# BE3_82       1637
# LQ1_sb       1637
# LQ_5EQL      1637
# BE3_33       1637
# BP6_2        1637
# BE3_78       1637
# LQ4_10       1637
# educ         1637
# BP_PHQ_1     1637
# BE3_84       1637
# LQ4_22       1637
# BS5_1        1637
# LQ4_14       1637
# BS3_3        1637
# BS1_1        1637
# LQ4_16       1637
# BP_PHQ_4     1637
# LQ2_ab       1637
# LQ4_09       1637
# CH2_2        1637
# BE8_2        1637
# BS6_2_1      1637
# BP5          1637
# BE5_1        1637
# BD2          1637
# LQ4_13       1637
# EC_lgw_5     1637
# BS8_2        1637
# BE3_74       1637
# LQ4_06       1637
# LQ4_12       1637
# dtype: int64
